# %% [markdown]
# <a href="https://colab.research.google.com/github/DaraRahma536/ML/blob/main/UTS%3F/UTS1_ML_Dara_rev1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xgboost==2.0.3 polars
# !pip install optuna
# !pip install polars
# Out:
# Collecting xgboost==2.0.3
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (1.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==2.0.3) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==2.0.3) (1.16.3)
# Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 5.0 MB/s eta 0:00:00
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.1.2
#     Uninstalling xgboost-3.1.2:
#       Successfully uninstalled xgboost-3.1.2
# Successfully installed xgboost-2.0.3
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 6.9 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (1.31.0)

# %%
import pandas as pd
import numpy as np
import polars as pl

# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder
# from sklearn.metrics import roc_auc_score, classification_report
# from lightgbm import LGBMClassifier
# from sklearn.impute import SimpleImputer

# %%
# !pip install -q gdown

# kalian download semua file dari gdrive dibawah lalu buat folder (ex. midterm_folder)
# !gdown --folder 1qoyfQ0yXp9pgnp9zKwsRm0B-u0n-KopN -O midterm_folder
# Out:
# Retrieving folder contents
# Processing file 1FlTQDZijxi_AdhdPlxvcgKdSRlcbVrKk test_transaction.csv
# Processing file 18BxWO8J8QgLfWeFInaLnswSph4yNg2RL train_transaction.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1FlTQDZijxi_AdhdPlxvcgKdSRlcbVrKk
# From (redirected): https://drive.google.com/uc?id=1FlTQDZijxi_AdhdPlxvcgKdSRlcbVrKk&confirm=t&uuid=a820ad3e-3f27-4ccf-8275-676bfb067537
# To: /content/midterm_folder/test_transaction.csv
# 100% 613M/613M [00:07<00:00, 82.4MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=18BxWO8J8QgLfWeFInaLnswSph4yNg2RL
# From (redirected): https://drive.google.com/uc?id=18BxWO8J8QgLfWeFInaLnswSph4yNg2RL&confirm=t&uuid=8b16f5fa-1e51-427d-9f8f-33effb3a5488
# To: /content/midterm_folder/train_transaction.csv
# 100% 683M/683M [00:10<00:00, 66.1MB/s]
# Download completed

# %%
BASE_PATH = "midterm_folder"

train_transaction = pl.read_csv(f"{BASE_PATH}/train_transaction.csv")
test_transaction  = pl.read_csv(f"{BASE_PATH}/test_transaction.csv")

# print(train_transaction.shape) #590540 row dan 393 feature + 1 target
# print(test_transaction.shape) #506691 row dan 393 feature

# %%
train_transaction.head() #isFraud adalah target featurenya
# Out:
# shape: (5, 394)
# ┌───────────────┬─────────┬───────────────┬────────────────┬───┬──────┬──────┬──────┬──────┐
# │ TransactionID ┆ isFraud ┆ TransactionDT ┆ TransactionAmt ┆ … ┆ V336 ┆ V337 ┆ V338 ┆ V339 │
# │ ---           ┆ ---     ┆ ---           ┆ ---            ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---  │
# │ i64           ┆ i64     ┆ i64           ┆ f64            ┆   ┆ f64  ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════════════╪═════════╪═══════════════╪════════════════╪═══╪══════╪══════╪══════╪══════╡
# │ 2987000       ┆ 0       ┆ 86400         ┆ 68.5           ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 2987001       ┆ 0       ┆ 86401         ┆ 29.0           ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 2987002       ┆ 0       ┆ 86469         ┆ 59.0           ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 2987003       ┆ 0       ┆ 86499         ┆ 50.0           ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 2987004       ┆ 0       ┆ 86506         ┆ 50.0           ┆ … ┆ 0.0  ┆ 0.0  ┆ 0.0  ┆ 0.0  │
# └───────────────┴─────────┴───────────────┴────────────────┴───┴──────┴──────┴──────┴──────┘

# %%
test_transaction.head() #uji data baru, setelah pembuatan model machine learningnya
# Out:
# shape: (5, 393)
# ┌───────────────┬───────────────┬────────────────┬───────────┬───┬──────┬──────┬──────┬──────┐
# │ TransactionID ┆ TransactionDT ┆ TransactionAmt ┆ ProductCD ┆ … ┆ V336 ┆ V337 ┆ V338 ┆ V339 │
# │ ---           ┆ ---           ┆ ---            ┆ ---       ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---  │
# │ i64           ┆ i64           ┆ f64            ┆ str       ┆   ┆ f64  ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════════════╪═══════════════╪════════════════╪═══════════╪═══╪══════╪══════╪══════╪══════╡
# │ 3663549       ┆ 18403224      ┆ 31.95          ┆ W         ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 3663550       ┆ 18403263      ┆ 49.0           ┆ W         ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 3663551       ┆ 18403310      ┆ 171.0          ┆ W         ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 3663552       ┆ 18403310      ┆ 284.95         ┆ W         ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 3663553       ┆ 18403317      ┆ 67.95          ┆ W         ┆ … ┆ null ┆ null ┆ null ┆ null │
# └───────────────┴───────────────┴────────────────┴───────────┴───┴──────┴──────┴──────┴──────┘

# %% [markdown]
# ### **Pakai CPU Saja**

# %% [markdown]
# ### **4.0**

# %%
# !pip install optuna-integration[lightgbm]
# Out:
# Collecting optuna-integration[lightgbm]
#   Downloading optuna_integration-4.6.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (from optuna-integration[lightgbm]) (4.6.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (from optuna-integration[lightgbm]) (4.6.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from optuna-integration[lightgbm]) (1.6.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from lightgbm->optuna-integration[lightgbm]) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lightgbm->optuna-integration[lightgbm]) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna->optuna-integration[lightgbm]) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna->optuna-integration[lightgbm]) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna->optuna-integration[lightgbm]) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna->optuna-integration[lightgbm]) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna->optuna-integration[lightgbm]) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna->optuna-integration[lightgbm]) (6.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->optuna-integration[lightgbm]) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->optuna-integration[lightgbm]) (3.6.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna->optuna-integration[lightgbm]) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (3.0.3)
# Downloading optuna_integration-4.6.0-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: optuna-integration
# Successfully installed optuna-integration-4.6.0

# %%
# !pip install --upgrade lightgbm optuna
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lightgbm) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)

# %%
# ======================================================
# 1. IMPORT LIBRARIES
# ======================================================
import polars as pl
import lightgbm as lgb
from lightgbm import LGBMClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score
import optuna
import os
import optuna.integration.lightgbm as lgb_tuner

# from optuna.integration import lightgbm as lgb_tuner
# from lightgbm import LightGBMTunerCV
from sklearn.model_selection import StratifiedKFold

# %%
# ======================================================
# 2. LOAD DATASET WITH POLARS
# ======================================================
# train_transactions = pl.read_csv("train_transaction.csv")
# test_transactions  = pl.read_csv("test_transaction.csv")

target = "isFraud"

# %%
# =======================================================
# 3. SPLIT NUMERIC & CATEGORICAL COLUMNS & IMPUTATION
# =======================================================
num_cols = [c for c, t in zip(train_transaction.columns, train_transaction.dtypes)
            if t in (pl.Float32, pl.Float64, pl.Int64, pl.Int32) and c != target]

cat_cols = [c for c, t in zip(train_transaction.columns, train_transaction.dtypes)
            if t == pl.Utf8]

# numeric → median
for col in num_cols:
    med = train_transaction[col].median()
    train_transaction = train_transaction.with_columns(pl.col(col).fill_null(med))
    test_transaction  = test_transaction.with_columns(pl.col(col).fill_null(med))

# categorical → missing
for col in cat_cols:
    train_transaction = train_transaction.with_columns(pl.col(col).fill_null("missing"))
    test_transaction  = test_transaction.with_columns(pl.col(col).fill_null("missing"))

# %%
# =======================================================
# 4. LABEL ENCODING (HANYA POLARS)
# =======================================================
for col in cat_cols:
    # Ambil seluruh nilai unik
    unique_vals = (
        pl.concat([train_transaction[col], test_transaction[col]])
        .unique()
        .to_list()
    )

    # Buat mapping integer
    mapping = {v: i for i, v in enumerate(unique_vals)}

    # Terapkan ke train & test (Polars)
    train_transaction = train_transaction.with_columns(
        pl.col(col).replace(mapping).cast(pl.Int64)
    )
    test_transaction = test_transaction.with_columns(
        pl.col(col).replace(mapping).cast(pl.Int64)
    )

# %%
# ======================================================
# 5. SAVE CLEANED DATA TO CSV (FOR STREAMING MODE)
# ======================================================

# train_transaction.write_csv("train_clean.csv")
# test_transaction.write_csv("test_clean.csv")

# # Save labels separately (LightGBM needs it)
# y_list = train_transaction[target].to_list()
# pl.DataFrame({"isFraud": y_list}).write_csv("train_label.csv")

# feature_cols = [c for c in train_transaction.columns if c != target]


# train_transaction = train_transaction.sample(frac=1.0, shuffle=True)

# val_size = int(0.2 * train_transaction.height)

# val_df = train_transaction[:val_size]
# train_transaction2 = train_transaction[val_size:]

# X_train = train_transaction2.drop(target).to_numpy()
# y_train = train_transaction2[target].to_numpy()

# X_val   = val_df.drop(target).to_numpy()
# y_val   = val_df[target].to_numpy()



# train_lgb = lgb.Dataset(X_train, label=y_train)
# valid_lgb = lgb.Dataset(X_val, label=y_val)

# %%
# ======================================================
# 6. LIGHTGBM STREAMING DATASET
# ======================================================

# train_data = lgb.Dataset(
#     "train_clean.csv",
#     label="train_label.csv",
#     params={
#         "header": True,
#         "label_column": "isFraud",
#     }
# )

# %%
# print(train_transaction["isFraud"].dtype)
# print(train_transaction.dtypes)
# Out:
# Int64
# [Float64, Int64, Float64, Float64, Int64, Float64, Float64, Float64, Int64, Float64, Int64, Float64, Float64, Float64, Float64, Int64, Int64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64]

# %%
# =======================================================
# 5. CONVERT TO LIGHTGBM DATASET ONCE (ANTI-CRASH)
# =======================================================
X = train_transaction.drop(target).to_pandas()  # safe (done once)
y = train_transaction[target].to_pandas()

train_lgb = lgb.Dataset(X, label=y)

# %%
# ======================================================
# 7. OPTUNA TUNING (STREAMING MODE)
# ======================================================
# def objective(trial):
#     params = {
#         "objective": "binary",
#         "metric": "auc",
#         "boosting_type": "gbdt",
#         "verbosity": -1,
#         "num_leaves": trial.suggest_int("num_leaves", 31, 255),
#         "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.05),
#         "feature_fraction": trial.suggest_float("feature_fraction", 0.6, 1.0),
#         "bagging_fraction": trial.suggest_float("bagging_fraction", 0.6, 1.0),
#         "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
#         "min_child_samples": trial.suggest_int("min_child_samples", 20, 200),
#         "n_estimators": trial.suggest_int("n_estimators", 200, 1000),
#         "device": "cpu"
#     }

#     model = lgb.train(params, train_data)

#     # Evaluate on a small validation set (to keep RAM low)
#     val_sample = train_transaction.sample(50000)
#     X_val = val_sample.select(feature_cols).to_pandas()
#     y_val = val_sample[target].to_pandas()

#     preds = model.predict(X_val)
#     auc = roc_auc_score(y_val, preds)

#     return auc


# study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=10)  # keep small for safety

# best_params = study.best_params
# best_params.update({
#     "objective": "binary",
#     "metric": "auc",
#     "device": "cpu"
# })

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
params = {
    "objective": "binary",
    "metric": "auc",
    "verbosity": -1,
    "boosting_type": "gbdt",
}

tuner = lgb_tuner.LightGBMTunerCV(
    params,
    train_lgb,
    folds=folds,
    # fit_kwargs={
    #     "early_stopping_rounds": 50,
    #     "verbose_eval": False  # <-- pindahkan ke sini
    # }
)

tuner.run()  # <<== OPTUNA tidak crash karena LGBMTuner sangat stabil

best_params = tuner.best_params
best_score = tuner.best_score

print("Best params:", best_params)
print("Best AUC:", best_score)
# Out:
# [I 2025-12-03 02:17:31,997] A new study created in memory with name: no-name-f55a0fed-dab3-4b80-a8f9-f3010dfafc67
# feature_fraction, val_score: -inf:   0%|          | 0/7 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# feature_fraction, val_score: 0.962305:  14%|#4        | 1/7 [08:14<49:29, 494.85s/it][I 2025-12-03 02:25:46,858] Trial 0 finished with value: 0.9623045017062848 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.9623045017062848.
# feature_fraction, val_score: 0.962305:  14%|#4        | 1/7 [08:14<49:29, 494.85s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# feature_fraction, val_score: 0.962305:  29%|##8       | 2/7 [17:57<45:33, 546.67s/it][I 2025-12-03 02:35:29,795] Trial 1 finished with value: 0.961199105968989 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.9623045017062848.
# feature_fraction, val_score: 0.962305:  29%|##8       | 2/7 [17:57<45:33, 546.67s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# feature_fraction, val_score: 0.962305:  43%|####2     | 3/7 [34:50<50:37, 759.48s/it][I 2025-12-03 02:52:22,528] Trial 2 finished with value: 0.9605580346952719 and parameters: {'feature_fraction': 0.5}. Best is trial 0 with value: 0.9623045017062848.
# feature_fraction, val_score: 0.962305:  43%|####2     | 3/7 [34:50<50:37, 759.48s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# feature_fraction, val_score: 0.962305:  57%|#####7    | 4/7 [42:48<32:24, 648.33s/it][I 2025-12-03 03:00:20,466] Trial 3 finished with value: 0.9615018951436151 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 0.9623045017062848.
# feature_fraction, val_score: 0.962305:  57%|#####7    | 4/7 [42:48<32:24, 648.33s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# feature_fraction, val_score: 0.962305:  71%|#######1  | 5/7 [58:35<25:12, 756.10s/it][I 2025-12-03 03:16:07,654] Trial 4 finished with value: 0.9607919702185196 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.9623045017062848.
# feature_fraction, val_score: 0.962305:  71%|#######1  | 5/7 [58:35<25:12, 756.10s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# feature_fraction, val_score: 0.962305:  86%|########5 | 6/7 [1:06:31<11:00, 660.96s/it][I 2025-12-03 03:24:03,939] Trial 5 finished with value: 0.9622310622640061 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 0 with value: 0.9623045017062848.
# feature_fraction, val_score: 0.962305:  86%|########5 | 6/7 [1:06:31<11:00, 660.96s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# feature_fraction, val_score: 0.962305: 100%|##########| 7/7 [1:14:24<00:00, 599.21s/it][I 2025-12-03 03:31:56,018] Trial 6 finished with value: 0.9611216644654501 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.9623045017062848.
# feature_fraction, val_score: 0.962305: 100%|##########| 7/7 [1:14:24<00:00, 637.72s/it]
# num_leaves, val_score: 0.962305:   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.965754:   5%|5         | 1/20 [08:21<2:38:47, 501.44s/it][I 2025-12-03 03:40:17,469] Trial 7 finished with value: 0.9657537105595946 and parameters: {'num_leaves': 39}. Best is trial 7 with value: 0.9657537105595946.
# num_leaves, val_score: 0.965754:   5%|5         | 1/20 [08:21<2:38:47, 501.44s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973718:  10%|#         | 2/20 [22:01<3:26:35, 688.66s/it][I 2025-12-03 03:53:57,187] Trial 8 finished with value: 0.9737176758771394 and parameters: {'num_leaves': 174}. Best is trial 8 with value: 0.9737176758771394.
# num_leaves, val_score: 0.973718:  10%|#         | 2/20 [22:01<3:26:35, 688.66s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973718:  15%|#5        | 3/20 [36:01<3:34:41, 757.73s/it][I 2025-12-03 04:07:57,098] Trial 9 finished with value: 0.9734101622863683 and parameters: {'num_leaves': 186}. Best is trial 8 with value: 0.9737176758771394.
# num_leaves, val_score: 0.973718:  15%|#5        | 3/20 [36:01<3:34:41, 757.73s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  20%|##        | 4/20 [51:56<3:42:54, 835.90s/it][I 2025-12-03 04:23:52,848] Trial 10 finished with value: 0.9737729015256316 and parameters: {'num_leaves': 244}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  20%|##        | 4/20 [51:56<3:42:54, 835.90s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  25%|##5       | 5/20 [1:08:17<3:42:03, 888.24s/it][I 2025-12-03 04:40:13,877] Trial 11 finished with value: 0.9733205501633814 and parameters: {'num_leaves': 256}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  25%|##5       | 5/20 [1:08:17<3:42:03, 888.24s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  30%|###       | 6/20 [1:22:26<3:24:05, 874.71s/it][I 2025-12-03 04:54:22,317] Trial 12 finished with value: 0.9735375619501344 and parameters: {'num_leaves': 191}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  30%|###       | 6/20 [1:22:26<3:24:05, 874.71s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  35%|###5      | 7/20 [1:38:42<3:16:42, 907.89s/it][I 2025-12-03 05:10:38,527] Trial 13 finished with value: 0.9735315798453502 and parameters: {'num_leaves': 253}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  35%|###5      | 7/20 [1:38:42<3:16:42, 907.89s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  40%|####      | 8/20 [1:51:07<2:51:14, 856.19s/it][I 2025-12-03 05:23:04,005] Trial 14 finished with value: 0.9733004722820866 and parameters: {'num_leaves': 144}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  40%|####      | 8/20 [1:51:07<2:51:14, 856.19s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  45%|####5     | 9/20 [2:01:01<2:21:53, 773.95s/it][I 2025-12-03 05:32:57,124] Trial 15 finished with value: 0.97033804888039 and parameters: {'num_leaves': 77}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  45%|####5     | 9/20 [2:01:01<2:21:53, 773.95s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  50%|#####     | 10/20 [2:15:09<2:12:48, 796.87s/it][I 2025-12-03 05:47:05,310] Trial 16 finished with value: 0.9736782800446424 and parameters: {'num_leaves': 193}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  50%|#####     | 10/20 [2:15:09<2:12:48, 796.87s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  55%|#####5    | 11/20 [2:27:19<1:56:27, 776.40s/it][I 2025-12-03 05:59:15,320] Trial 17 finished with value: 0.9733390282183858 and parameters: {'num_leaves': 137}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  55%|#####5    | 11/20 [2:27:19<1:56:27, 776.40s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  60%|######    | 12/20 [2:42:27<1:48:52, 816.53s/it][I 2025-12-03 06:14:23,627] Trial 18 finished with value: 0.9732235050829454 and parameters: {'num_leaves': 218}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  60%|######    | 12/20 [2:42:27<1:48:52, 816.53s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  65%|######5   | 13/20 [2:53:13<1:29:13, 764.85s/it][I 2025-12-03 06:25:09,548] Trial 19 finished with value: 0.9718035386721013 and parameters: {'num_leaves': 101}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  65%|######5   | 13/20 [2:53:13<1:29:13, 764.85s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  70%|#######   | 14/20 [3:06:23<1:17:14, 772.42s/it][I 2025-12-03 06:38:19,452] Trial 20 finished with value: 0.9733149044999191 and parameters: {'num_leaves': 163}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  70%|#######   | 14/20 [3:06:23<1:17:14, 772.42s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  75%|#######5  | 15/20 [3:21:13<1:07:19, 807.97s/it][I 2025-12-03 06:53:09,834] Trial 21 finished with value: 0.9736641790462244 and parameters: {'num_leaves': 213}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  75%|#######5  | 15/20 [3:21:13<1:07:19, 807.97s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  80%|########  | 16/20 [3:36:18<55:48, 837.10s/it]  [I 2025-12-03 07:08:14,564] Trial 22 finished with value: 0.9735080854793745 and parameters: {'num_leaves': 220}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  80%|########  | 16/20 [3:36:18<55:48, 837.10s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.973773:  85%|########5 | 17/20 [3:49:51<41:29, 829.95s/it][I 2025-12-03 07:21:47,878] Trial 23 finished with value: 0.9735403071935125 and parameters: {'num_leaves': 176}. Best is trial 10 with value: 0.9737729015256316.
# num_leaves, val_score: 0.973773:  85%|########5 | 17/20 [3:49:51<41:29, 829.95s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.974063:  90%|######### | 18/20 [4:05:20<28:39, 859.52s/it][I 2025-12-03 07:37:16,244] Trial 24 finished with value: 0.9740626221024897 and parameters: {'num_leaves': 230}. Best is trial 24 with value: 0.9740626221024897.
# num_leaves, val_score: 0.974063:  90%|######### | 18/20 [4:05:20<28:39, 859.52s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.974063:  95%|#########5| 19/20 [4:21:37<14:54, 894.80s/it][I 2025-12-03 07:53:33,221] Trial 25 finished with value: 0.9733257915981923 and parameters: {'num_leaves': 237}. Best is trial 24 with value: 0.9740626221024897.
# num_leaves, val_score: 0.974063:  95%|#########5| 19/20 [4:21:37<14:54, 894.80s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# num_leaves, val_score: 0.974063: 100%|##########| 20/20 [4:37:31<00:00, 912.78s/it][I 2025-12-03 08:09:27,926] Trial 26 finished with value: 0.9733113641044564 and parameters: {'num_leaves': 229}. Best is trial 24 with value: 0.9740626221024897.
# num_leaves, val_score: 0.974063: 100%|##########| 20/20 [4:37:31<00:00, 832.60s/it]
# bagging, val_score: 0.974063:   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# bagging, val_score: 0.974063:  10%|#         | 1/10 [29:10<4:22:37, 1750.84s/it][I 2025-12-03 08:38:38,773] Trial 27 finished with value: 0.9734326815731855 and parameters: {'bagging_fraction': 0.8876402792079083, 'bagging_freq': 2}. Best is trial 24 with value: 0.9740626221024897.
# bagging, val_score: 0.974063:  10%|#         | 1/10 [29:10<4:22:37, 1750.84s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# bagging, val_score: 0.974063:  20%|##        | 2/10 [49:21<3:11:02, 1432.81s/it][I 2025-12-03 08:58:48,962] Trial 28 finished with value: 0.9058874713786539 and parameters: {'bagging_fraction': 0.41560158797890445, 'bagging_freq': 7}. Best is trial 24 with value: 0.9740626221024897.
# bagging, val_score: 0.974063:  20%|##        | 2/10 [49:21<3:11:02, 1432.81s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# bagging, val_score: 0.974063:  30%|###       | 3/10 [1:11:28<2:41:31, 1384.54s/it][I 2025-12-03 09:20:56,064] Trial 29 finished with value: 0.9663895538707921 and parameters: {'bagging_fraction': 0.5456947482341579, 'bagging_freq': 6}. Best is trial 24 with value: 0.9740626221024897.
# bagging, val_score: 0.974063:  30%|###       | 3/10 [1:11:28<2:41:31, 1384.54s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# bagging, val_score: 0.974063:  40%|####      | 4/10 [1:27:24<2:01:34, 1215.70s/it][I 2025-12-03 09:36:52,934] Trial 30 finished with value: 0.9738578722912766 and parameters: {'bagging_fraction': 0.989834052415812, 'bagging_freq': 1}. Best is trial 24 with value: 0.9740626221024897.
# bagging, val_score: 0.974063:  40%|####      | 4/10 [1:27:25<2:01:34, 1215.70s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# bagging, val_score: 0.974063:  50%|#####     | 5/10 [1:43:15<1:33:20, 1120.12s/it][I 2025-12-03 09:52:43,570] Trial 31 finished with value: 0.9735064766612714 and parameters: {'bagging_fraction': 0.9995918219500112, 'bagging_freq': 1}. Best is trial 24 with value: 0.9740626221024897.
# bagging, val_score: 0.974063:  50%|#####     | 5/10 [1:43:15<1:33:20, 1120.12s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# bagging, val_score: 0.974063:  60%|######    | 6/10 [2:07:13<1:21:52, 1228.16s/it][I 2025-12-03 10:16:41,450] Trial 32 finished with value: 0.9712298309204312 and parameters: {'bagging_fraction': 0.7610823733514336, 'bagging_freq': 4}. Best is trial 24 with value: 0.9740626221024897.
# bagging, val_score: 0.974063:  60%|######    | 6/10 [2:07:13<1:21:52, 1228.16s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# bagging, val_score: 0.974063:  70%|#######   | 7/10 [2:32:41<1:06:18, 1326.29s/it][I 2025-12-03 10:42:09,788] Trial 33 finished with value: 0.97114451486636 and parameters: {'bagging_fraction': 0.7496885825169145, 'bagging_freq': 3}. Best is trial 24 with value: 0.9740626221024897.
# bagging, val_score: 0.974063:  70%|#######   | 7/10 [2:32:41<1:06:18, 1326.29s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# bagging, val_score: 0.974063:  80%|########  | 8/10 [2:48:38<40:16, 1208.48s/it]  [I 2025-12-03 10:58:06,009] Trial 34 finished with value: 0.9738182603551924 and parameters: {'bagging_fraction': 0.9927512590057344, 'bagging_freq': 1}. Best is trial 24 with value: 0.9740626221024897.
# bagging, val_score: 0.974063:  80%|########  | 8/10 [2:48:38<40:16, 1208.48s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# bagging, val_score: 0.974063:  90%|######### | 9/10 [3:04:34<18:49, 1129.66s/it][I 2025-12-03 11:14:02,377] Trial 35 finished with value: 0.9740180141080499 and parameters: {'bagging_fraction': 0.9852512118558934, 'bagging_freq': 1}. Best is trial 24 with value: 0.9740626221024897.
# bagging, val_score: 0.974063:  90%|######### | 9/10 [3:04:34<18:49, 1129.66s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# bagging, val_score: 0.974171: 100%|##########| 10/10 [3:20:30<00:00, 1076.03s/it][I 2025-12-03 11:29:58,291] Trial 36 finished with value: 0.9741711217268614 and parameters: {'bagging_fraction': 0.978743820106045, 'bagging_freq': 1}. Best is trial 36 with value: 0.9741711217268614.
# bagging, val_score: 0.974171: 100%|##########| 10/10 [3:20:30<00:00, 1203.04s/it]
# feature_fraction_stage2, val_score: 0.974171:   0%|          | 0/3 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# feature_fraction_stage2, val_score: 0.974171:  33%|###3      | 1/3 [15:46<31:32, 946.33s/it][I 2025-12-03 11:45:44,632] Trial 37 finished with value: 0.9740024912529748 and parameters: {'feature_fraction': 0.9520000000000001}. Best is trial 36 with value: 0.9741711217268614.
# feature_fraction_stage2, val_score: 0.974171:  33%|###3      | 1/3 [15:46<31:32, 946.33s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# feature_fraction_stage2, val_score: 0.974334:  67%|######6   | 2/3 [31:20<15:39, 939.39s/it][I 2025-12-03 12:01:19,168] Trial 38 finished with value: 0.9743337956049579 and parameters: {'feature_fraction': 0.9840000000000001}. Best is trial 38 with value: 0.9743337956049579.
# feature_fraction_stage2, val_score: 0.974334:  67%|######6   | 2/3 [31:20<15:39, 939.39s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# feature_fraction_stage2, val_score: 0.974334: 100%|##########| 3/3 [46:55<00:00, 937.42s/it][I 2025-12-03 12:16:54,234] Trial 39 finished with value: 0.9741661961870204 and parameters: {'feature_fraction': 0.92}. Best is trial 38 with value: 0.9743337956049579.
# feature_fraction_stage2, val_score: 0.974334: 100%|##########| 3/3 [46:55<00:00, 938.65s/it]
# regularization_factors, val_score: 0.974334:   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# regularization_factors, val_score: 0.974334:   5%|5         | 1/20 [17:27<5:31:37, 1047.24s/it][I 2025-12-03 12:34:21,484] Trial 40 finished with value: 0.9736019167134407 and parameters: {'lambda_l1': 1.5744388607434964e-07, 'lambda_l2': 0.20238786408447026}. Best is trial 38 with value: 0.9743337956049579.
# regularization_factors, val_score: 0.974334:   5%|5         | 1/20 [17:27<5:31:37, 1047.24s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# regularization_factors, val_score: 0.974334:  10%|#         | 2/20 [38:20<5:50:30, 1168.36s/it][I 2025-12-03 12:55:14,628] Trial 41 finished with value: 0.9705438981884814 and parameters: {'lambda_l1': 6.118820064099618, 'lambda_l2': 1.162643008690762e-08}. Best is trial 38 with value: 0.9743337956049579.
# regularization_factors, val_score: 0.974334:  10%|#         | 2/20 [38:20<5:50:30, 1168.36s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# regularization_factors, val_score: 0.974334:  15%|#5        | 3/20 [55:30<5:13:09, 1105.26s/it][I 2025-12-03 13:12:24,795] Trial 42 finished with value: 0.9739542096463627 and parameters: {'lambda_l1': 0.03265453064017615, 'lambda_l2': 1.5118706697775094e-06}. Best is trial 38 with value: 0.9743337956049579.
# regularization_factors, val_score: 0.974334:  15%|#5        | 3/20 [55:30<5:13:09, 1105.26s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# regularization_factors, val_score: 0.974334:  20%|##        | 4/20 [1:15:14<5:02:59, 1136.24s/it][I 2025-12-03 13:32:08,529] Trial 43 finished with value: 0.9734113311956862 and parameters: {'lambda_l1': 2.6184648979417662e-08, 'lambda_l2': 1.7749320472735444}. Best is trial 38 with value: 0.9743337956049579.
# regularization_factors, val_score: 0.974334:  20%|##        | 4/20 [1:15:14<5:02:59, 1136.24s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# regularization_factors, val_score: 0.974334:  25%|##5       | 5/20 [1:32:23<4:34:24, 1097.63s/it][I 2025-12-03 13:49:17,705] Trial 44 finished with value: 0.9736052612748793 and parameters: {'lambda_l1': 6.989161865903815e-05, 'lambda_l2': 0.00318452641034732}. Best is trial 38 with value: 0.9743337956049579.
# regularization_factors, val_score: 0.974334:  25%|##5       | 5/20 [1:32:23<4:34:24, 1097.63s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(
# regularization_factors, val_score: 0.974334:  30%|###       | 6/20 [1:49:22<4:09:52, 1070.86s/it][I 2025-12-03 14:06:16,598] Trial 45 finished with value: 0.9740364375887115 and parameters: {'lambda_l1': 0.00012317518243906947, 'lambda_l2': 5.615135532904379e-05}. Best is trial 38 with value: 0.9743337956049579.
# regularization_factors, val_score: 0.974334:  30%|###       | 6/20 [1:49:22<4:09:52, 1070.86s/it]/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:877: UserWarning: The groups parameter is ignored by StratifiedKFold
#   warnings.warn(

# %%
# ======================================================
# 8. TRAIN FINAL MODEL (STREAMING MODE)
# ======================================================
final_model = lgb.train(best_params, train_lgb)

# %%
X_test = test_transaction.drop("TransactionID").to_pandas()
test_pred = final_model.predict(X_test)

submission = pl.DataFrame({
    "TransactionID": test_transaction["TransactionID"],
    "isFraud": test_pred
})

submission.write_csv("submission_done.csv")
print("Done! Saved as submission_done.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1722820336.py in <cell line: 0>()
#       1 X_test = test_transaction.drop("TransactionID").to_pandas()
# ----> 2 test_pred = train_lgb.predict(X_test)
#       3
#       4 submission = pl.DataFrame({
#       5     "TransactionID": test_transaction["TransactionID"],
#
# AttributeError: 'Dataset' object has no attribute 'predict'
